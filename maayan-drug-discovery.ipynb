# %%
"""Class for reading, parsing, and downloading data from the Drugmonizome API.
   Adapted fromo harmonizome.py.
   https://github.com/MaayanLab/Drugmonizome-ML/blob/master/drugmonizome.py
"""

import gzip
import json
import os
import logging

# Support for both Python2.X and 3.X.
# -----------------------------------------------------------------------------
try:
    import io
    from urllib.request import urlopen
    from urllib.error import HTTPError
    from urllib.parse import quote_plus
except ImportError:
    from StringIO import StringIO
    from urllib2 import urlopen, HTTPError
    from urllib import quote_plus

try:
    input_shim = raw_input
except NameError:
    # If `raw_input` throws a `NameError`, the user is using Python 2.X.
    input_shim = input

import pandas as pd
import numpy as np
from scipy.sparse import lil_matrix, isspmatrix
from itertools import takewhile, repeat
from functools import reduce

def parse_gmt(fn, row_sep='\n', col_sep='\t'):
    '''
    Parser for reading Drugmonizome data in gmt format (ragged tsv)
    Each row is a drug set corresponding to a term
    First column is term ID, second column is empty, remaining columns are drug IDs (as InChI keys)
    
    Returns:
        dict: maps term ID to sets of associated drugs
    '''
    terms_to_drugs = {}
    with open(fn, 'r', newline=row_sep) as fh:
        for line in fh:
            lh = line.strip().split('\t')
            assert lh[1] == '', 'unexpected input format'
            terms_to_drugs[lh[0]] = set(lh[2:])
    return terms_to_drugs

def parse_gmt_to_df(fn, row_sep='\n', col_sep='\t'):
    '''
    Parser for reading Drugmonizome data in gmt format (ragged tsv)
    Each row is a drug set corresponding to a term
    First column is term ID, second column is empty, remaining columns are drug IDs (as InChI keys)
    
    Returns:
        dataframe: indices are drug IDs, columns are term IDs, filled with 1 if association and 0 otherwise
    '''
    terms_to_drugs = parse_gmt(fn, row_sep=row_sep, col_sep=col_sep)
    all_drugs = reduce(lambda s1, s2: s1.union(s2), terms_to_drugs.values())
    df = pd.DataFrame(0, index=sorted(all_drugs), columns=sorted(terms_to_drugs))
    for term in terms_to_drugs:
        df.loc[terms_to_drugs[term], term] = 1
    return df

def parse_multiple(fns, row_sep='\n', col_sep='\t'):
    '''
    Reads multiple Drugmonizome datasets and joins dataframe by shared drug IDs
    Parser for reading Drugmonizome data in gmt format (ragged tsv)
    Each row is a drug set corresponding to a term
    First column is term ID, second column is empty, remaining columns are drug IDs (as InChI keys)
    
    Returns:
        dataframe: indices are drug IDs, columns are term IDs, filled with 1 if association and 0 otherwise
    '''
    # Load individual datasets
    df_attributes = [parse_gmt_to_df(fn) for fn in fns]
    
    # Assemble all attribute datasets
    if len(df_attributes) > 1:
        # Obtain merged dataframe with omics and target data
        df = reduce(
            lambda a, b: pd.merge( # Merge two dataframes item by item
                a, # left
                b, # right
                # Items with the same left and right index are merged
                left_index=True,
                right_index=True,
                how='outer', # Keep mis-matched index
        ),
        df_attributes,
    )
    else:
        df = df_attributes[0]
    return df

def get_matches_df(drugmonizome_metadata, hits):
    '''
    Matches a list of drug screen hits to the appropriate Drugmonizome metadata.
    Looks for a full match between the name of the hit and the Name or a
    synonym of a drug.
    
    Param:
     - drugmonizome_metadata: dataframe with Drugmonizome metadata
     - hits: list/set of str names of drug screen hits
    
    Returns:
     - dataframe containing metadata for drug screen hits
    '''
    # format the set of hits
    hits = set(hit.strip().lower() for hit in hits if len(hit.strip()) > 0)
    print('Number of hits queried: {}'.format(len(hits)))
    
    # make boolean array for drugs in Drugmonizome, where a match to a hit is True
    in_name = np.array([drug.lower() in hits for drug in drugmonizome_metadata['Name']])
    in_synonyms = np.array([any(drug.strip().lower() in hits for drug in synonyms)
                            if isinstance(synonyms, list) else False
                            for synonyms in drugmonizome_metadata['Synonyms']])
    
    print('Number of matches: {} / {}'.format(np.sum(np.logical_or(in_synonyms, in_name)), len(drugmonizome_metadata)))
    
    # find unmatched drugs
    hits_name_copy = set(hits)
    for drug in drugmonizome_metadata['Name']:
        if drug.lower() in hits_name_copy:
            hits_name_copy.remove(drug.lower())

    hits_syn_copy = set(hits)
    for synonyms in drugmonizome_metadata['Synonyms']:
        if isinstance(synonyms, str): 
            for drug in synonyms:
                if drug.strip().lower() in hits_syn_copy:
                    hits_syn_copy.remove(drug.strip().lower())

    missing_hits = hits_name_copy.intersection(hits_syn_copy)
    print('Missing in Drugmonizome ({}): {}'.format(len(missing_hits), missing_hits))
    
    # filter hits metadata
    dfhits = drugmonizome_metadata.loc[np.logical_or(in_synonyms, in_name)]
    print('Total shape: {}'.format(dfhits.shape))
          
    return dfhits

# Enumerables and constants
# -----------------------------------------------------------------------------

class Enum(set):
    """Simple Enum shim since Python 2.X does not have them.
    """

    def __getattr__(self, name):
        if name in self:
            return name
        raise AttributeError


def json_from_url(url):
    """Returns API response after decoding and loading JSON.
    """
    response = urlopen(url)
    data = response.read().decode('utf-8')
    return json.loads(data)


VERSION = 'v1'
API_URL = 'http://maayanlab.cloud/drugmonizome/data-api/api'
METADATA_URL = 'https://maayanlab.cloud/drugmonizome/metadata-api/entities'

# # This config objects pulls the names of the datasets, their directories, and
# # the possible downloads from the API. This allows us to add new datasets and
# # downloads without breaking this file.
# config = json_from_url('https://maayanlab.cloud/drugmonizome/metadata-api/libraries')
# DATASET_TO_LINK = {x['meta']['Library_name']: x['meta']['Download_link'] for x in config}

# Static version of Drugmonizome datasets, as the Drugmonizome resource is temporarily unavailable
LINK_BASE = 'https://appyters.maayanlab.cloud/storage/Drugmonizome_ML/DrugmonizomeGMTs/'
DATASET_TO_LINK = {
    'L1000FWD Downregulated GO Biological Processes': LINK_BASE + 'L1000FWD/L1000FWD_GO_Biological_Processes_drugsetlibrary_down.gmt',
    'L1000FWD Downregulated GO Cellular Components': LINK_BASE + 'L1000FWD/L1000FWD_GO_Cellular_Component_drugsetlibrary_down.gmt',
    'L1000FWD Downregulated GO Molecular Function': LINK_BASE + 'L1000FWD/L1000FWD_GO_Molecular_Function_drugsetlibrary_down.gmt',
    'L1000FWD Downregulated KEGG Pathways': LINK_BASE + 'L1000FWD/L1000FWD_KEGG_Pathways_drugsetlibrary_down.gmt',
    'L1000FWD Downregulated Signatures': LINK_BASE + 'L1000FWD/L1000FWD_signature_drugsetlibrary_down.gmt',
    'L1000FWD Predicted Side Effects': LINK_BASE + 'L1000FWD/L1000FWD_predicted_side_effects.gmt',
    'L1000FWD Upregulated GO Biological Process': LINK_BASE + 'L1000FWD/L1000FWD_GO_Biological_Processes_drugsetlibrary_up.gmt',
    'L1000FWD Upregulated GO Cellular Components': LINK_BASE + 'L1000FWD/L1000FWD_GO_Cellular_Component_drugsetlibrary_up.gmt',
    'L1000FWD Upregulated GO Molecular Function': LINK_BASE + 'L1000FWD/L1000FWD_GO_Molecular_Function_drugsetlibrary_up.gmt',
    'L1000FWD Upregulated KEGG Pathways': LINK_BASE + 'L1000FWD/L1000FWD_KEGG_Pathways_drugsetlibrary_up.gmt',
    'L1000FWD Upregulated Signatures': LINK_BASE + 'L1000FWD/L1000FWD_signature_drugsetlibrary_up.gmt',
    'Downregulated CREEDS Signatures': LINK_BASE + 'CREEDS/CREEDS_signature_drugsetlibrary_down.gmt',
    'Upregulated CREEDS Signatures': LINK_BASE + 'CREEDS/CREEDS_signature_drugsetlibrary_up.gmt',
    'DrugCentral Targets': LINK_BASE + 'DrugCentral/DrugCentral_target_drugsetlibrary.gmt',
    'DrugRepurposingHub Drug Targets': LINK_BASE + 'DrugRepurposingHub/DrugRepurposingHub_target_drugsetlibrary.gmt',
    'Drugbank Small Molecule Carriers': LINK_BASE + 'Drugbank/Drugbank_smallmolecule_carrier_drugsetlibrary.gmt',
    'Drugbank Small Molecule Enzymes': LINK_BASE + 'Drugbank/Drugbank_smallmolecule_enzyme_drugsetlibrary.gmt',
    'Drugbank Small Molecule Targets': LINK_BASE + 'Drugbank/Drugbank_smallmolecule_target_drugsetlibrary.gmt',
    'Drugbank Small Molecule Transporters': LINK_BASE + 'Drugbank/Drugbank_smallmolecule_transporter_drugsetlibrary.gmt',
    'Geneshot Associated Genes': LINK_BASE + 'Geneshot/Geneshot_associated_drugsetlibrary.gmt',
    'Geneshot Predicted AutoRIF Genes': LINK_BASE + 'Geneshot/Geneshot_predicted_autorif_drugsetlibrary.gmt',
    'Geneshot Predicted Coexpression Genes': LINK_BASE + 'Geneshot/Geneshot_predicted_coexpression_drugsetlibrary.gmt',
    'Geneshot Predicted Enrichr Genes': LINK_BASE + 'Geneshot/Geneshot_predicted_enrichr_drugsetlibrary.gmt',
    'Geneshot Predicted GeneRIF Genes': LINK_BASE + 'Geneshot/Geneshot_predicted_generif_drugsetlibrary.gmt',
    'Geneshot Predicted Tagger Genes': LINK_BASE + 'Geneshot/Geneshot_predicted_tagger_drugsetlibrary.gmt',
    'KinomeScan Kinases': LINK_BASE + 'KinomeScan/KinomeScan_kinase_drugsetlibrary.gmt',
    'PharmGKB Single Nucleotide Polymorphisms': LINK_BASE + 'PharmGKB/PharmGKB_snp_drugsetlibrary.gmt',
    'STITCH Targets': LINK_BASE + 'STITCH/STITCH_genes_drugsetlibrary.gmt',
    'ATC Codes Drugsetlibrary': LINK_BASE + 'ATC/ATC_drugsetlibrary.gmt',
    'DrugRepurposingHub Mechanisms of Action': LINK_BASE + 'DrugRepurposingHub/DrugRepurposingHub_moa_drugsetlibrary.gmt',
    'PharmGKB OFFSIDES Side Effects': LINK_BASE + 'PharmGKB/PharmGKB_OFFSIDES_side_effects_drugsetlibrary.gmt',
    'SIDER Indications': LINK_BASE + 'SIDER/SIDER_indications_drugsetlibrary.gmt',
    'SIDER Side Effects': LINK_BASE + 'SIDER/SIDER_side_effects_drugsetlibrary.gmt',
    'RDKIT MACCS Chemical Fingerprints': LINK_BASE + 'RDKIT/RDKIT_maccs_fingerprints_drugsetlibrary_updated.gmt',
}

# Drugmonizome class
# -----------------------------------------------------------------------------

class Drugmonizome(object):

    __version__ = VERSION
    DATASETS = DATASET_TO_LINK.keys()
    drug_metadata = None

    @classmethod
    def get(cls, entity, name=None, start_at=None):
        """Returns a single entity or a list, depending on if a name is
        provided. If no name is provided and start_at is specified, returns a
        list starting at that cursor position.
        """
        if name:
            name = quote_plus(name)
            return _get_by_name(entity, name)
        if start_at is not None and type(start_at) is int:
            return _get_with_cursor(entity, start_at)
        url = '%s/%s/%s' % (API_URL, VERSION, entity)
        result = json_from_url(url)
        return result

    @classmethod
    def next(cls, response):
        """Returns the next set of entities based on a previous API response.
        """
        start_at = _get_next(response)
        entity = _get_entity(response)
        return cls.get(entity=entity, start_at=start_at)

    @classmethod
    def download(cls, datasets=None):
        """For each dataset, creates a directory and downloads files into it.
        """
        # Why not check `if not datasets`? Because in principle, a user could 
        # call `download([])`, which should download nothing, not everything.
        # Why might they do this? Imagine that the list of datasets is
        # dynamically generated in another user script.
        if datasets is None:
            datasets = cls.DATASETS
            warning = 'Warning: You are going to download all Harmonizome '\
                      'data. This is roughly 30GB. Do you accept?\n(Y/N) '
            resp = input_shim(warning)
            if resp.lower() != 'y':
                return

        for dataset in datasets:
            if dataset not in cls.DATASETS:
                msg = '"%s" is not a valid dataset name. Check the `DATASETS`'\
                      ' property for a complete list of names.' % dataset
                raise AttributeError(msg)
            if not os.path.exists(dataset):
                os.mkdir(dataset)
            
            url = DATASET_TO_LINK[dataset]

            try:
                response = urlopen(url)
                print('test')
            except HTTPError as e:
                # Not every dataset has all downloads.
                raise Exception('Error downloading from %s: %s' % (url, e))
            
            filename = '%s/%s' % (dataset, url.split('/')[-1])

            if response.code != 200:
                raise Exception('This should not happen')
            
            if os.path.isfile(filename):
                logging.info('Using cached `%s`' % (filename))
            else:
                _download_file(response, filename)
                
            return filename

    @classmethod
    def download_df(cls, datasets=None, **kwargs):
        for file in cls.download(datasets):
            return _read_as_dataframe(file, **kwargs)
    
    @classmethod
    def get_datasets(cls):
        return cls.DATASETS
    
    @classmethod
    def read_drug_metadata(cls):
        """Reads all drug metadata into a dataframe
        """
        if cls.drug_metadata is None:
            entities = json_from_url(METADATA_URL)
            rows_list = []
            for entity in entities:
                rows_list.append(entity['meta'])
            cls.drug_metadata = pd.DataFrame(rows_list)
        return cls.drug_metadata

    @classmethod
    def get_InChI_keys(cls, hits):
        """Given list of drug names, finds matching InChI keys in Drugmonizome
        """
        df_drugs = cls.read_drug_metadata()
        df_hits = get_matches_df(df_drugs, hits)
        return list(df_hits['InChI_key'])
    
    @classmethod
    def map_names_to_inchi_keys(cls, hits):
        """Given list of drug names, finds matching InChI keys in Drugmonizome
           and returns dictionary mapping names to associated InChI keys
        """
        hits = set(hit.lower() for hit in hits)
        df_drugs = cls.read_drug_metadata()
        name_to_inchis = {}
        for i in range(len(df_drugs)):
            compound = df_drugs.iloc[i]
            if isinstance(compound.Synonyms, list):
                names = [compound.Name] + compound.Synonyms
            else:
                names = [compound.Name]
            for name in names:
                name = name.lower().strip()
                if name not in name_to_inchis:
                    name_to_inchis[name] = set()
                name_to_inchis[name].add(compound.InChI_key)
        return {hit: name_to_inchis[hit] for hit in hits if hit in name_to_inchis}
    
    @classmethod
    def get_drug_names(cls, inchi_keys):
        """Given list of InChI keys, finds matching drug names in Drugmonizome
        """
        df_drugs = cls.read_drug_metadata()
        df_drugs = df_drugs.set_index('InChI_key')
        return list(df_drugs.reindex(inchi_keys)['Name'])

# Utility functions
# -------------------------------------------------------------------------

def _get_with_cursor(entity, start_at):
    """Returns a list of entities based on cursor position.
    """
    url = '%s/%s/%s?cursor=%s' % (API_URL, VERSION, entity,str(start_at))
    result = json_from_url(url)
    return result


def _get_by_name(entity, name):
    """Returns a single entity based on name.
    """
    url = '%s/%s/%s/%s' % (API_URL, VERSION, entity, name)
    return json_from_url(url)


def _get_entity(response):
    """Returns the entity from an API response.
    """
    path = response['next'].split('?')[0]
    return path.split('/')[3]


def _get_next(response):
    """Returns the next property from an API response.
    """
    if response['next']:
        return int(response['next'].split('=')[1])
    return None


# This function was adopted from here: http://stackoverflow.com/a/15353312.
# def _download_and_decompress_file(response, filename):
#     """Downloads and decompresses a single file from a response object.
#     """
#     compressed_file = StringIO()
#     compressed_file.write(response.read())
#     compressed_file.seek(0)
#     decompressed_file = gzip.GzipFile(fileobj=compressed_file, mode='rb')
#     with open(filename, 'w+') as outfile:
#         outfile.write(decompressed_file.read())

def _download_file(response, filename):
    """
    """
    file = io.BytesIO(response.read())

    with open(filename, 'wb+') as outfile:
        outfile.write(file.read())


def json_ind_no_slash(ind_names, ind):
  return (
      json.dumps([ind_name.replace('/', '|')
                 for ind_name in ind_names]),
      [json.dumps([ii.replace('/', '|')
                  for ii in i])
       for i in ind],
  )

def _read_as_dataframe(fn):
    ''' Standard loading of dataframe '''
    # return fn
    print(fn)
    import pandas as pd
    if fn.endswith('.gmt'):
        return parse_gmt_to_df(fn)
    else:
        raise Exception('Unable to parse this file into a dataframe.')

# %%
Drugmonizome.download(['L1000FWD Upregulated KEGG Pathways'])
Drugmonizome.download(['L1000FWD Downregulated KEGG Pathways'])
# Out:
# test
# test
# 'L1000FWD Downregulated KEGG Pathways/L1000FWD_KEGG_Pathways_drugsetlibrary_down.gmt'

# %%
df_upregulated = parse_gmt_to_df('L1000FWD Upregulated KEGG Pathways/L1000FWD_KEGG_Pathways_drugsetlibrary_up.gmt')
df_upregulated = df_upregulated.loc[df_upregulated['Colorectal cancer'] == 1]
df_downregulated = parse_gmt_to_df('L1000FWD Downregulated KEGG Pathways/L1000FWD_KEGG_Pathways_drugsetlibrary_down.gmt')
df_downregulated = df_downregulated.loc[df_downregulated['Colorectal cancer'] == 1]
display(df_upregulated)
display(df_downregulated)
# Out:
#                              ABC transporters  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                 0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                 0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                 0
# AICKZRPQDLFSPA-SREVYHEPSA-N                 0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                 0
# ...                                       ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                 0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                 0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                 0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                 0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                 0
#
#                              AGE-RAGE signaling pathway in diabetic complications  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                                  1
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                                  1
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                                  1
# AICKZRPQDLFSPA-SREVYHEPSA-N                                                  0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                                  1
# ...                                                                        ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                                                  0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                                                  0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                                                  0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                                                  1
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                                                  0
#
#                              AMPK signaling pathway  Acute myeloid leukemia  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                       1                       0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                       1                       0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                       0                       0
# AICKZRPQDLFSPA-SREVYHEPSA-N                       1                       1
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                       0                       0
# ...                                             ...                     ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                       0                       0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                       0                       0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                       0                       0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                       0                       0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                       0                       0
#
#                              Adherens junction  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                  0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                  0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                  0
# AICKZRPQDLFSPA-SREVYHEPSA-N                  0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                  0
# ...                                        ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                  0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                  0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                  0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                  0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                  0
#
#                              Adipocytokine signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                0
# ...                                                      ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                                0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                                0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                                0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                                0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                                0
#
#                              Adrenergic signaling in cardiomyocytes  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                       0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                       0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                       0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                       0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                       0
# ...                                                             ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                                       0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                                       0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                                       0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                                       0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                                       0
#
#                              African trypanosomiasis  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                        0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                        0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                        0
# AICKZRPQDLFSPA-SREVYHEPSA-N                        0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                        0
# ...                                              ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                        0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                        0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                        0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                        0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                        0
#
#                              Alanine, aspartate and glutamate metabolism  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                            0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                            0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                            0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                            0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                            0
# ...                                                                  ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                                            0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                                            0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                                            0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                                            0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                                            0
#
#                              Alcoholism  ...  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N           1  ...
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N           0  ...
# AFJYYKSVHJGXSN-XUCDQRGXSA-N           0  ...
# AICKZRPQDLFSPA-SREVYHEPSA-N           0  ...
# AJVXVYTVAAWZAP-UHFFFAOYSA-N           0  ...
# ...                                 ...  ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N           1  ...
# ZOCUOMKMBMEYQV-GSLJADNHSA-N           0  ...
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N           0  ...
# ZXGGCBQORXDVTE-UMCMBGNQSA-N           0  ...
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N           0  ...
#
#                              Vasopressin-regulated water reabsorption  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                         0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                         0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                         0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                         0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                         0
# ...                                                               ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                                         0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                                         0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                                         0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                                         0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                                         0
#
#                              Vibrio cholerae infection  Viral carcinogenesis  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                          0                     1
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                          0                     1
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                          0                     1
# AICKZRPQDLFSPA-SREVYHEPSA-N                          0                     0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                          0                     0
# ...                                                ...                   ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                          0                     1
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                          0                     0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                          0                     0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                          0                     1
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                          0                     0
#
#                              Viral myocarditis  Wnt signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                  0                      0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                  0                      0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                  0                      0
# AICKZRPQDLFSPA-SREVYHEPSA-N                  0                      0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                  0                      0
# ...                                        ...                    ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                  0                      1
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                  0                      0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                  0                      0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                  1                      0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                  0                      0
#
#                              beta-Alanine metabolism  cAMP signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                        0                       0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                        0                       0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                        0                       0
# AICKZRPQDLFSPA-SREVYHEPSA-N                        0                       0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                        0                       0
# ...                                              ...                     ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                        0                       0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                        0                       0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                        0                       0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                        0                       0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                        0                       0
#
#                              cGMP-PKG signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                           0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                           0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                           0
# AICKZRPQDLFSPA-SREVYHEPSA-N                           0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                           0
# ...                                                 ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                           0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                           0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                           0
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                           0
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                           0
#
#                              mTOR signaling pathway  p53 signaling pathway
# AATCBLYHOUOCTO-UHFFFAOYSA-N                       0                      1
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                       0                      1
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                       0                      1
# AICKZRPQDLFSPA-SREVYHEPSA-N                       0                      0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                       0                      0
# ...                                             ...                    ...
# ZHJGWYRLJUCMRT-QGZVFWFLSA-N                       0                      0
# ZOCUOMKMBMEYQV-GSLJADNHSA-N                       0                      0
# ZSTFBDBEPIYXAW-UHFFFAOYSA-N                       0                      1
# ZXGGCBQORXDVTE-UMCMBGNQSA-N                       0                      1
# ZZUZYEMRHCMVTB-UHFFFAOYSA-N                       0                      0
#
# [244 rows x 245 columns]
#                              AGE-RAGE signaling pathway in diabetic complications  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                                                  0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                                                  1
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                                                  0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                                                  0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                                                  1
# ...                                                                        ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                                  1
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                                  1
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                                  1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                                  1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                                  0
#
#                              AMPK signaling pathway  Acute myeloid leukemia  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                       0                       0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                       0                       0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                       0                       0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                       0                       0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                       0                       0
# ...                                             ...                     ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                       0                       1
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                       0                       0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                       0                       0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                       0                       0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                       0                       0
#
#                              Adherens junction  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                  0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                  0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                  1
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                  0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                  0
# ...                                        ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                  0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                  0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                  0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                  0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                  0
#
#                              Adipocytokine signaling pathway  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                                0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                                0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                                0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                                0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                                0
# ...                                                      ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                0
#
#                              Adrenergic signaling in cardiomyocytes  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                                       0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                                       0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                                       0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                                       0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                                       0
# ...                                                             ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                       0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                       0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                       0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                       0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                       0
#
#                              African trypanosomiasis  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                        0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                        0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                        0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                        0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                        0
# ...                                              ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                        0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                        0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                        1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                        1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                        0
#
#                              Alanine, aspartate and glutamate metabolism  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                                            0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                                            0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                                            0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                                            0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                                            0
# ...                                                                  ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                            0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                            0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                            0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                            0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                            0
#
#                              Alcoholism  Aldosterone synthesis and secretion  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N           0                                    0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N           0                                    0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N           0                                    0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N           0                                    0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N           0                                    0
# ...                                 ...                                  ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N           0                                    0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N           0                                    0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N           0                                    0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N           0                                    0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N           0                                    0
#
#                              ...  Valine, leucine and isoleucine degradation  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N  ...                                           0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N  ...                                           0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N  ...                                           0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N  ...                                           0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N  ...                                           0
# ...                          ...                                         ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N  ...                                           0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N  ...                                           0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N  ...                                           0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N  ...                                           0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N  ...                                           0
#
#                              Vascular smooth muscle contraction  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                                   0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                                   0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                                   0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                                   0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                                   0
# ...                                                         ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                   0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                   0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                   0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                   0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                   0
#
#                              Vibrio cholerae infection  Viral carcinogenesis  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                          0                     0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                          0                     0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                          0                     1
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                          0                     0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                          0                     0
# ...                                                ...                   ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                          0                     0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                          0                     0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                          0                     0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                          0                     0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                          0                     0
#
#                              Viral myocarditis  Wnt signaling pathway  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                  0                      1
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                  0                      1
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                  0                      1
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                  0                      0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                  0                      0
# ...                                        ...                    ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                  1                      1
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                  0                      0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                  0                      0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                  0                      0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                  0                      1
#
#                              beta-Alanine metabolism  cAMP signaling pathway  \
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                        0                       0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                        0                       0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                        0                       0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                        0                       0
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                        0                       0
# ...                                              ...                     ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                        0                       0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                        0                       0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                        0                       0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                        0                       0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                        0                       0
#
#                              cGMP-PKG signaling pathway  p53 signaling pathway
# ATUYSKUVHUPXBV-ZFORQUDYSA-N                           0                      0
# AYUNIORJHRXIBJ-TXHRRWQRSA-N                           0                      0
# BBFQZRXNYIEMAW-UHFFFAOYSA-N                           0                      0
# BPRHUIZQVSMCRT-VEUZHWNKSA-N                           0                      1
# CTKNMSVWMRRCPW-UHFFFAOYSA-N                           0                      1
# ...                                                 ...                    ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                           0                      0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                           0                      0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                           0                      1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                           0                      1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                           0                      1
#
# [73 rows x 236 columns]

# %%
# def suggest_drugs_from_cms(cms):
# https://docs.google.com/spreadsheets/d/1aQC-TRxuAzGLwLgKeh8sJXHyK78OZjY9iIx-G1aOA0U/edit#gid=0
#     if cms == 1: 
#         search_terms = [];
#     elif cms == 2: 
#         search_terms = [];
#     elif cms == 3: 
#         search_terms = [];
#     elif cms == 4: 
#         search_terms = [];
#     return search_terms

df = pd.concat([df_upregulated,df_downregulated], sort=False)
display(df)
print(len(df))
# Out:
#                              ABC transporters  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N               0.0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N               0.0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N               0.0
# AICKZRPQDLFSPA-SREVYHEPSA-N               0.0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N               0.0
# ...                                       ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N               NaN
# XZZYCJOGZYEPPW-UHFFFAOYSA-N               NaN
# ZRBJORGEGBDMJS-UHFFFAOYSA-N               NaN
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N               NaN
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N               NaN
#
#                              AGE-RAGE signaling pathway in diabetic complications  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                                  1
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                                  1
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                                  1
# AICKZRPQDLFSPA-SREVYHEPSA-N                                                  0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                                  1
# ...                                                                        ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                                  1
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                                  1
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                                  1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                                  1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                                  0
#
#                              AMPK signaling pathway  Acute myeloid leukemia  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                       1                       0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                       1                       0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                       0                       0
# AICKZRPQDLFSPA-SREVYHEPSA-N                       1                       1
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                       0                       0
# ...                                             ...                     ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                       0                       1
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                       0                       0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                       0                       0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                       0                       0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                       0                       0
#
#                              Adherens junction  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                  0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                  0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                  0
# AICKZRPQDLFSPA-SREVYHEPSA-N                  0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                  0
# ...                                        ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                  0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                  0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                  0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                  0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                  0
#
#                              Adipocytokine signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                0
# ...                                                      ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                0
#
#                              Adrenergic signaling in cardiomyocytes  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                       0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                       0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                       0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                       0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                       0
# ...                                                             ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                       0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                       0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                       0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                       0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                       0
#
#                              African trypanosomiasis  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                        0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                        0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                        0
# AICKZRPQDLFSPA-SREVYHEPSA-N                        0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                        0
# ...                                              ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                        0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                        0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                        1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                        1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                        0
#
#                              Alanine, aspartate and glutamate metabolism  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                            0
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                            0
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                            0
# AICKZRPQDLFSPA-SREVYHEPSA-N                                            0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                            0
# ...                                                                  ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                            0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                            0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                            0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                            0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                            0
#
#                              Alcoholism  ...  p53 signaling pathway  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N           1  ...                      1
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N           0  ...                      1
# AFJYYKSVHJGXSN-XUCDQRGXSA-N           0  ...                      1
# AICKZRPQDLFSPA-SREVYHEPSA-N           0  ...                      0
# AJVXVYTVAAWZAP-UHFFFAOYSA-N           0  ...                      0
# ...                                 ...  ...                    ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N           0  ...                      0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N           0  ...                      0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N           0  ...                      1
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N           0  ...                      1
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N           0  ...                      1
#
#                              Collecting duct acid secretion  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                             NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                             NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                             NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                             NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                             NaN
# ...                                                     ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                             0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                             0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                             0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                             0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                             0.0
#
#                              Glyoxylate and dicarboxylate metabolism  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                      NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                      NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                      NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                                      NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                      NaN
# ...                                                              ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                      0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                      0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                      0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                      0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                      0.0
#
#                              Homologous recombination  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                       NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                       NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                       NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                       NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                       NaN
# ...                                               ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                       0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                       0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                       0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                       0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                       0.0
#
#                              One carbon pool by folate  Purine metabolism  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                        NaN                NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                        NaN                NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                        NaN                NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                        NaN                NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                        NaN                NaN
# ...                                                ...                ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                        0.0                0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                        0.0                0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                        0.0                0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                        0.0                0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                        0.0                0.0
#
#                              Pyrimidine metabolism  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                    NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                    NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                    NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                    NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                    NaN
# ...                                            ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                    0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                    0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                    0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                    0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                    0.0
#
#                              Retrograde endocannabinoid signaling  \
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                   NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                   NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                   NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                                   NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                   NaN
# ...                                                           ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                   0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                   0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                   0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                   0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                   0.0
#
#                              Ribosome biogenesis in eukaryotes  Thermogenesis
# AATCBLYHOUOCTO-UHFFFAOYSA-N                                NaN            NaN
# ACNKWXDVXVEMDQ-UHFFFAOYSA-N                                NaN            NaN
# AFJYYKSVHJGXSN-XUCDQRGXSA-N                                NaN            NaN
# AICKZRPQDLFSPA-SREVYHEPSA-N                                NaN            NaN
# AJVXVYTVAAWZAP-UHFFFAOYSA-N                                NaN            NaN
# ...                                                        ...            ...
# XTEUDLFCDXLLCT-HNNXBMFYSA-N                                0.0            0.0
# XZZYCJOGZYEPPW-UHFFFAOYSA-N                                0.0            0.0
# ZRBJORGEGBDMJS-UHFFFAOYSA-N                                0.0            0.0
# ZRDIMGZPSNNFQF-UHFFFAOYSA-N                                0.0            0.0
# ZVPDNRVYHLRXLX-UHFFFAOYSA-N                                0.0            0.0
#
# [317 rows x 254 columns]
# 317

# %%
def suggest_drugs(search_nodes):
    drug_database = Drugmonizome.read_drug_metadata()
    
    drugs = drug_database.loc[drug_database['InChI_key'].isin(list(df.index.values))]
    urllist = drugs.Download_url.tolist()

    output_drugs = []; 
    for drug_n, drug_json_url in enumerate(urllist):
        json_associations = json_from_url(drug_json_url)['Associations']
        drug_targets = []; drug_name = ''
        for j in range(0, len(json_associations)):
            temp = json_associations[j]
            for k in search_terms:
                if k in temp['Term'][0]['Name']:
                    drug_targets.append(temp['Term'][0]['Name'])
                    if drug_name == '':
                        drug_name = str(drugs.Name.tolist()[drug_n])

        output_drugs.append([drug_name, drug_targets])    
        
    return output_drugs

# %%
search_terms = ["ERK", "EGF", "TGFA", "EREG", "AREG", "EGFR", "KRAS", "NRAS", "PI3K", "RalGDS"]
output_drugs = suggest_drugs(search_terms)
output_drugs
# Out:
# [['chlorambucil',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'KRAS']],
#  ['perhexiline',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'HBEGF',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway']],
#  ['lopinavir',
#   ['VEGFA',
#    'AREG',
#    'VEGFC',
#    'VEGFA',
#    'VEGFD',
#    'TGFA',
#    'EGF',
#    'VEGFA',
#    'PI3K-Akt signaling pathway']],
#  ['yl-54',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'HBEGF',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['vu-0410183-2', ['EGFR', 'EGFR', 'VEGFA', 'EREG']],
#  ['brd-k75477256',
#   ['PI3K-Akt signaling pathway',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'EGFR',
#    'EGFR',
#    'MEGF9']],
#  ['1-(2,3-dihydro-1,4-benzodioxin-6-ylsulfonyl)-4-[(4-methoxyphenyl)sulfonyl]piperazine',
#   ['PI3K-Akt signaling pathway',
#    'VEGF signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['paclitaxel',
#   ['PI3K-Akt signaling pathway',
#    'VEGF signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EREG',
#    'HBEGF',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['norethisterone', ['AREG', 'KRAS', 'EGF', 'TGFA']],
#  ['etoposide',
#   ['VEGFA',
#    'PI3K-Akt signaling pathway',
#    'HBEGF',
#    'MEGF9',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['gw-6471',
#   ['MEGF9',
#    'EGFL6',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-a59145032',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'KRAS', 'EREG', 'AREG']],
#  ['idarubicin', ['KRAS', 'EGFR', 'EGFR', 'EGF', 'EGFR', 'EGFR', 'VEGFA']],
#  ['brd-a82913781', ['EREG', 'PI3K-Akt signaling pathway']],
#  ['digitoxin', ['AREG', 'EREG', 'NRAS', 'EGFR', 'EGFR', 'VEGFA']],
#  ['', []],
#  ['docosatrienoic-acid', ['AREG', 'EREG', 'TGFA']],
#  ['brd-k02216544',
#   ['PI3K-Akt signaling pathway', 'VEGF signaling pathway', 'AREG', 'VEGFA']],
#  ['brd-k02562327',
#   ['negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k07161233',
#   ['PI3K-Akt signaling pathway', 'AREG', 'VEGFA', 'EGFR', 'EGFR']],
#  ['brd-k08307026',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['ku-0060648', ['EGFL6', 'EREG']],
#  ['md-ii-008-p',
#   ['TGFA',
#    'KRAS',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway',
#    'VEGF signaling pathway']],
#  ['mek1-2-inhibitor', ['HBEGF', 'EREG', 'AREG', 'EGFR', 'EGFR', 'TGFA']],
#  ['brd-k14788918',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'AREG', 'TGFA']],
#  ['brazilin',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['ku-c104254',
#   ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'KRAS', 'VEGFC']],
#  ['jtc-801',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['mw-stk33-2c',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'AREG', 'KRAS', 'VEGFD']],
#  ['brd-k21009077', ['AREG', 'EREG', 'HBEGF', 'EGF']],
#  ['piperlongumine',
#   ['VEGFA',
#    'EGFL6',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k26160061', ['EREG', 'EGFR', 'EGFR']],
#  ['rifapentine', ['KRAS', 'EGFR', 'EGFR', 'PI3K-Akt signaling pathway']],
#  ['ketoconazole',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'MEGF9',
#    'VEGFC']],
#  ['brd-k31706415',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'VEGFA',
#    'EGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['sildenafil',
#   ['VEGFB',
#    'AREG',
#    'TGFA',
#    'EGF',
#    'VEGFA',
#    'HBEGF',
#    'AREG',
#    'TGFA',
#    'EREG',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k35004659', ['PI3K-Akt signaling pathway', 'TGFA', 'HBEGF', 'VEGFA']],
#  ['torin-1',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'AREG', 'TGFA', 'VEGFA']],
#  ['cinanserin', ['VEGFA', 'AREG']],
#  ['brd-k41925105',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['epicatechin',
#   ['TGFA',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'PI3K-Akt signaling pathway',
#    'VEGF signaling pathway']],
#  ['ebelactone-b',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'KRAS',
#    'AREG',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['brd-k66224104', ['EGFR', 'EGFR']],
#  ['ql-x-138', ['EGFR', 'EGFR', 'TGFA']],
#  ['ikk-2-inhibitor-v',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'HBEGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['km-00927', ['VEGFA']],
#  ['tyrphostin-47',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA']],
#  ['topotecan',
#   ['EGFR',
#    'EGFR',
#    'HBEGF',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGFLAM',
#    'EGFL6',
#    'EGFL6']],
#  ['brd-k06009608', ['AREG', 'KRAS']],
#  ['artemether', ['KRAS', 'AREG']],
#  ['tamatinib',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'TGFA',
#    'VEGFC',
#    'PI3K-Akt signaling pathway']],
#  ['brd-a04172077', ['EGFR', 'EGFR']],
#  ['cvf-sumo-7',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EREG',
#    'AREG',
#    'PI3K-Akt signaling pathway']],
#  ['cyclosporin-a',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'VEGFC',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['selamectin',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['rottlerin',
#   ['VEGFA',
#    'VEGFC',
#    'MEGF9',
#    'TGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k05153001',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'KRAS',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['angiogenesis-inhibitor',
#   ['PI3K-Akt signaling pathway',
#    'VEGFA',
#    'MEGF9',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['cs-110266', ['PI3K-Akt signaling pathway', 'AREG', 'TGFA', 'EGFL6']],
#  ['aristolochic-acid', ['EREG', 'EGFR', 'EGFR']],
#  ['yl-59', ['AREG']],
#  ['fenretinide',
#   ['EREG',
#    'HBEGF',
#    'MEGF9',
#    'EGF',
#    'NRAS',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'CERK',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['sa-1017940', ['PI3K-Akt signaling pathway', 'AREG', 'KRAS']],
#  ['brd-k67470788',
#   ['EGFR', 'EGFR', 'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['yl-55', ['PI3K-Akt signaling pathway', 'AREG', 'HBEGF', 'MEGF9']],
#  ['rizatriptan', ['AREG', 'VEGFA', 'HBEGF', 'EREG', 'VEGFB', 'VEGFA']],
#  ['pioglitazone', ['VEGFA', 'AREG', 'VEGFB']],
#  ['7-[4-(dimethylamino)phenyl]-n-hydroxy-4,6-dimethyl-7-oxo-2,4-heptadienamide',
#   ['VEGFA',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k40300908',
#   ['KRAS',
#    'AREG',
#    'EGF',
#    'PI3K-Akt signaling pathway',
#    'VEGF signaling pathway']],
#  ['tanespimycin',
#   ['VEGFA',
#    'EGFR',
#    'EGFR',
#    'KRAS',
#    'HBEGF',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'TGFA',
#    'NRAS',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway']],
#  ['cardarine', ['AREG', 'EREG', 'MEGF9']],
#  ['sns-314', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'HBEGF']],
#  ['pazopanib',
#   ['VEGFA',
#    'AREG',
#    'VEGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'VEGFR inhibitor',
#    'VEGFR inhibitor',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'VEGFB',
#    'TGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'KRAS',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'TGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR']],
#  ['brd-k60070073',
#   ['EREG',
#    'AREG',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway']],
#  ['5-[(2-methyl-5-{[3-(trifluoromethyl)phenyl]carbamoyl}phenyl)amino]pyridine-3-carboxamide',
#   ['EREG', 'TGFA', 'EGF']],
#  ['5-[(e)-(5-chloro-2-oxo-1,2-dihydro-3h-indol-3-ylidene)methyl]-n-[2-(diethylamino)ethyl]-2,4-dimethyl-1h-pyrrole-3-carboxamide',
#   ['AREG', 'EREG', 'VEGFA', 'EGFL6', 'TGFA']],
#  ['7b-cis', ['KRAS']],
#  ['brd-k62300190', ['EGFR', 'EGFR']],
#  ['brd-k62459624', ['VEGFA', 'EREG', 'AREG']],
#  ['brd-k65983740', ['AREG', 'EGFL6']],
#  ['fluvastatin',
#   ['KRAS',
#    'EGF',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'PI3K-Akt signaling pathway']],
#  ['gdc-0879', ['KRAS']],
#  ['geranylgeraniol', ['EGFL6', 'KRAS', 'EGFR', 'EGFR']],
#  ['amsacrine',
#   ['AREG',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'PI3K-Akt signaling pathway']],
#  ['saracatinib',
#   ['HBEGF',
#    'EREG',
#    'AREG',
#    'VEGFC',
#    'TGFA',
#    'VEGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'AREG',
#    'TGFA',
#    'KRAS',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'PI3K-Akt signaling pathway']],
#  ['protionamide', ['TGFA', 'VEGFA']],
#  ['brd-a68274214', ['EREG', 'KRAS']],
#  ['cidoxepin',
#   ['VEGFA',
#    'AREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-a08662020',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['bci-hydrochloride',
#   ['TGFA',
#    'HBEGF',
#    'EREG',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['scopolamine',
#   ['AREG', 'EGFL6', 'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['hu-211',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['latrunculin-b',
#   ['KRAS',
#    'HBEGF',
#    'EGFR',
#    'EGFR',
#    'TGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['calmidazolium',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['ter-14687',
#   ['PI3K-Akt signaling pathway',
#    'VEGFA',
#    'EREG',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['teniposide',
#   ['AREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'PI3K-Akt signaling pathway']],
#  ['periplocymarin',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'AREG', 'HBEGF']],
#  ['ouabain',
#   ['EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['ivermectin',
#   ['PI3K-Akt signaling pathway',
#    'TGFA',
#    'VEGFA',
#    'MEGF9',
#    'NRAS',
#    'EGFR',
#    'EGFR',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['vinblastine', ['EGFR', 'EGFR', 'HBEGF', 'EGFR', 'EGFR']],
#  ['k784-3131',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'AREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['hydroquinine', ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'KRAS']],
#  ['oxalomalic-acid',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'KRAS', 'EGFL6']],
#  ['brd-a81282034',
#   ['EREG',
#    'AREG',
#    'TGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-a94381689', ['PI3K-Akt signaling pathway', 'VEGFA']],
#  ['brd-k00430421',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'VEGFA',
#    'VEGFC',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['ag-14361',
#   ['AREG', 'EREG', 'HBEGF', 'KRAS', 'MEGF9', 'PI3K-Akt signaling pathway']],
#  ['brd-k00863322',
#   ['PI3K-Akt signaling pathway', 'VEGF signaling pathway', 'KRAS']],
#  ['nsc-663284', ['AREG', 'HBEGF', 'VEGFA']],
#  ['ryuvidine',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['narciclasine', ['AREG', 'VEGFA', 'EGFR', 'EGFR']],
#  ['benzo(a)pyrene',
#   ['EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['tosyllysyl-chloromethyl-ketone',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'MEGF9',
#    'VEGFA',
#    'EGFL6',
#    'EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k14027855', ['EGFR', 'EGFR', 'TGFA', 'VEGFA']],
#  ['brd-k14355517', ['AREG', 'EGFR', 'EGFR']],
#  ['ku-c104493', ['AREG', 'EREG', 'HBEGF']],
#  ['i-606051',
#   ['HBEGF',
#    'VEGFA',
#    'EGFL6',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['parthenolide',
#   ['EREG',
#    'AREG',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PI3K-Akt signaling pathway']],
#  ['mycophenolic-acid',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['brd-k33045404',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['rjc-00245sc',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['way-170523',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'VEGFA',
#    'EREG',
#    'EGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['nvp-auy922',
#   ['HBEGF',
#    'AREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k50746423',
#   ['EGFR',
#    'EGFR',
#    'MEGF9',
#    'EREG',
#    'VEGFC',
#    'TGFA',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k74623475', ['PI3K-Akt signaling pathway', 'AREG', 'HBEGF']],
#  ['brd-k78843060', ['PERK-mediated unfolded protein response (GO:0036499)']],
#  ['', []],
#  ['i-070759',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['fu-jmbii227b', ['EREG', 'AREG', 'PI3K-Akt signaling pathway']],
#  ['scopolamine',
#   ['PI3K-Akt signaling pathway',
#    'TGFA',
#    'VEGFA',
#    'HBEGF',
#    'TGFA',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'TGFA',
#    'HBEGF',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'EREG']],
#  ['tcs-359', ['EGFR', 'EGFR', 'VEGFA']],
#  ['ikk-inhibitor-x',
#   ['PI3K-Akt signaling pathway',
#    'VEGFA',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['xl-147',
#   ['AREG',
#    'EREG',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['alvespimycin',
#   ['EGFR',
#    'EGFR',
#    'VEGFA',
#    'TGFA',
#    'NRAS',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'TGFA',
#    'NRAS',
#    'EREG',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'EGFR',
#    'EGFR']],
#  ['vinorelbine', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR']],
#  ['rosuvastatin', ['HBEGF', 'EGF', 'VEGFA', 'EGF']],
#  ['1-ter-butyl-3-p-tolyl-1h-pyrazolo[3,4-d]pyrimidin-4-ylamine',
#   ['VEGFA', 'EREG', 'PI3K-Akt signaling pathway']],
#  ['sa-3676',
#   ['EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['flumetasone',
#   ['EGFR',
#    'EGFR',
#    'KRAS',
#    'MEGF9',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['methyltestosterone', ['EGFR', 'EGFR', 'AREG', 'EGF', 'EREG']],
#  ['bvt-948',
#   ['EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['megestrol',
#   ['EGFR',
#    'EGFR',
#    'KRAS',
#    'VEGFA',
#    'HBEGF',
#    'EGFL6',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['flurofamide', ['HBEGF', 'AREG', 'PI3K-Akt signaling pathway']],
#  ['alpha-linolenic acid', ['VEGFA', 'VEGFB', 'KRAS', 'VEGFA', 'CERK']],
#  ['metixene',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'CERK',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['rosiglitazone',
#   ['VEGFA',
#    'EGFR',
#    'EGFR',
#    'VEGFB',
#    'PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'EGFL6',
#    'VEGFD']],
#  ['ketorolac',
#   ['AREG',
#    'HBEGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'TGFA',
#    'EGFR',
#    'EGFR',
#    'VEGFB',
#    'TGFA',
#    'EREG',
#    'EREG',
#    'PI3K-Akt signaling pathway']],
#  ['fluticasone propionate',
#   ['VEGFC',
#    'VEGFA',
#    'VEGFA',
#    'EGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'TGFA',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'TGFA']],
#  ['chloroquine', ['MEGF9', 'AREG', 'KRAS', 'EGFR', 'EGFR']],
#  ['irinotecan',
#   ['EGFR',
#    'EGFR',
#    'NRAS',
#    'TGFA',
#    'KRAS',
#    'PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'TGFA',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'KRAS',
#    'EREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'KRAS']],
#  ['thalidomide',
#   ['VEGFA', 'EGFR', 'EGFR', 'EGF', 'MEGF9', 'VEGFA', 'TGFA', 'NRAS', 'VEGFA']],
#  ['tegaserod',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'VEGFA',
#    'TGFA',
#    'TGFA',
#    'EGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['moclobemide', ['EGFR', 'EGFR', 'TGFA', 'MEGF8']],
#  ['practolol',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'VEGFA',
#    'CERK',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'CERK']],
#  ['carbenoxolone',
#   ['HBEGF',
#    'PI3K-Akt signaling pathway',
#    'VEGF signaling pathway',
#    'KRAS',
#    'VEGFA',
#    'EREG',
#    'EREG']],
#  ['4-(3,14-dihydroxy-10,13-dimethyl-hexadecahydro-cyclopenta[a]phenanthren-17-yl)-5h-furan-2-one',
#   ['AREG', 'EREG']],
#  ['9-hydroxy-4-phenyl-6h-pyrrolo[3,4-c]carbazole-1,3-dione',
#   ['HBEGF',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['vx-702',
#   ['EGFR',
#    'EGFR',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['plinabulin',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['anisomycin',
#   ['EGFR',
#    'EGFR',
#    'EGFR',
#    'EGFR',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['nocodazole',
#   ['EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'EGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['carmofur',
#   ['PI3K-Akt signaling pathway', 'AREG', 'VEGFA', 'EGFR', 'EGFR', 'MEGF10']],
#  ['mosapride',
#   ['PI3K-Akt signaling pathway',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['benperidol',
#   ['VEGFB',
#    'MEGF8',
#    'PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'HBEGF']],
#  ['isoflupredone acetate',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'VEGFA',
#    'VEGFC',
#    'VEGFB',
#    'VEGFA',
#    'EREG',
#    'VEGFB',
#    'MEGF10',
#    'VEGFD',
#    'VEGFB',
#    'VEGFA']],
#  ['xanthohumol',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'TGFA',
#    'VEGFA',
#    'VEGFA',
#    'TGFA',
#    'KRAS',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'TGFA',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'VEGFB',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'TGFA']],
#  ['sb-218078', ['EREG', 'TGFA', 'HBEGF', 'PI3K-Akt signaling pathway']],
#  ['ipratropium', ['PI3K-Akt signaling pathway', 'TGFA']],
#  ['ambelline', ['EGFR', 'EGFR']],
#  ['triciribine',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway']],
#  ['nutlin-3', ['PI3K-Akt signaling pathway', 'AREG', 'TGFA', 'HBEGF']],
#  ['brefeldin-a',
#   ['MEGF9',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway']],
#  ['etoposide',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['bax-channel-blocker',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'KRAS',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['vinpocetine', ['VEGFA', 'KRAS', 'TGFA']],
#  ['vinblastine', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'VEGFA']],
#  ['brd-a24021119',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'TGFA',
#    'VEGFA',
#    'EREG']],
#  ['saclofen', ['EREG', 'AREG', 'PI3K-Akt signaling pathway']],
#  ['at-sumo-1',
#   ['PI3K-Akt signaling pathway',
#    'MEGF9',
#    'EREG',
#    'AREG',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['camptothecin',
#   ['EGFR',
#    'EGFR',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'ERK1 and ERK2 cascade (GO:0070371)',
#    'PI3K-Akt signaling pathway']],
#  ['homosalate', ['PI3K-Akt signaling pathway', 'AREG', 'HBEGF', 'VEGFC']],
#  ['fludrocortisone',
#   ['PI3K-Akt signaling pathway', 'AREG', 'VEGFA', 'HBEGF', 'VEGFA']],
#  ['radicicol', ['EGFL6', 'EREG', 'AREG']],
#  ['brd-a47816767', ['EGFR', 'EGFR', 'AREG', 'TGFA']],
#  ['', []],
#  ['ib-meca', ['AREG', 'PI3K-Akt signaling pathway']],
#  ['cucurbitacin-i',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-a49848186',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['withaferin-a',
#   ['PI3K-Akt signaling pathway', 'TGFA', 'HBEGF', 'KRAS', 'VEGFA']],
#  ['ingenol',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'TGFA',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['kf-38789', ['EREG', 'TGFA', 'EGFL6']],
#  ['cgp-54626', ['AREG']],
#  ['vincristine', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR']],
#  ['tremulacin', ['PI3K-Akt signaling pathway', 'AREG']],
#  ['cycloheximide', ['HBEGF']],
#  ['clobetasol',
#   ['AREG', 'EGF', 'EGF', 'EGFR', 'EGFR', 'PI3K-Akt signaling pathway']],
#  ['brd-a63949900', ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'VEGFC']],
#  ['', []],
#  ['f-1061-0166', ['VEGFA', 'EREG', 'AREG']],
#  ['manumycin-a', ['HBEGF', 'EREG', 'AREG']],
#  ['emf-sumo1-11',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EREG',
#    'MEGF9',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['floxuridine',
#   ['EGFR',
#    'EGFR',
#    'EREG',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['clofarabine', ['EGFR', 'EGFR', 'AREG', 'EREG', 'HBEGF', 'EGF']],
#  ['emf-sumo1-39',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'HBEGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['cvf-sumo-14',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'EREG',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['brd-k00289828', ['EREG', 'AREG']],
#  ['brd-k00954209',
#   ['HBEGF',
#    'EREG',
#    'AREG',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k01121114',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'VEGFA',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k01614657',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k03176945', ['EREG', 'EGFR', 'EGFR']],
#  ['brd-k03857568', ['PI3K-Akt signaling pathway', 'HBEGF']],
#  ['sb-222200', ['EREG', 'AREG', 'TGFA', 'PI3K-Akt signaling pathway']],
#  ['gsk-1904529a', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'AREG']],
#  ['brd-k05402890',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'EREG', 'EGFL6']],
#  ['az-628',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'EREG',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['brd-k06956503', ['KRAS', 'VEGFA', 'EGFR', 'EGFR']],
#  ['brd-k07023879',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'VEGFC',
#    'CERK',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k08463963', ['TGFA', 'MEGF9', 'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['sr-57227a', ['PI3K-Akt signaling pathway', 'EREG', 'VEGFA', 'HBEGF']],
#  ['nu-7026',
#   ['PI3K-Akt signaling pathway',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'EGF',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['bms-345541', ['PI3K-Akt signaling pathway', 'KRAS']],
#  ['obatoclax',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'HBEGF',
#    'VEGFC',
#    'NRAS',
#    'EGFR',
#    'EGFR',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['brd-k16331660',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['brd-k16541732',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'VEGFA',
#    'VEGFC',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['st-4029573', ['AREG', 'KRAS']],
#  ['daunorubicin',
#   ['ERK1 and ERK2 cascade (GO:0070371)',
#    'EGFR',
#    'EGFR',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k18726304',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['ku-c104224',
#   ['EREG',
#    'TGFA',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['lavendustin-a', ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'NRAS']],
#  ['ym-155',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'CERK',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['piceatannol', ['EGFR', 'EGFR', 'MEGF9', 'HBEGF']],
#  ['bix-01294', ['AREG', 'EREG']],
#  ['km-03949sc',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k28293491',
#   ['HBEGF',
#    'AREG',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['ran-05',
#   ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'KRAS', 'VEGFC', 'VEGFA']],
#  ['brd-k28916077',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['mw-stk33-2a', ['EREG', 'PI3K-Akt signaling pathway']],
#  ['', []],
#  ['cgp-53353',
#   ['PI3K-Akt signaling pathway', 'AREG', 'HBEGF', 'VEGFA', 'VEGFC']],
#  ['ver-155008', ['VEGFA', 'VEGFC', 'TGFA', 'PI3K-Akt signaling pathway']],
#  ['brd-k32944375', ['PI3K-Akt signaling pathway', 'AREG']],
#  ['inca-6',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'HBEGF',
#    'MEGF9',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k33926001', ['PI3K-Akt signaling pathway', 'VEGFA', 'EGFL6']],
#  ['naproxol', ['PI3K-Akt signaling pathway', 'AREG', 'HBEGF', 'VEGFA']],
#  ['brd-k34968258',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['sa-247714', ['AREG', 'TGFA']],
#  ['vu-0365114-2',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA']],
#  ['tyrphostin-a9',
#   ['EGFL6',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'PI3K-Akt signaling pathway',
#    'VEGF signaling pathway']],
#  ['ku-c104337',
#   ['VEGFA', 'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k41652870',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EREG',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['suloctidil',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['gsk-2126458', ['AREG', 'EREG']],
#  ['vu-0418946-1', ['PI3K-Akt signaling pathway', 'TGFA', 'VEGFA']],
#  ['brd-k44484254',
#   ['EGFL6', 'KRAS', 'AREG', 'EGFR', 'EGFR', 'PI3K-Akt signaling pathway']],
#  ['u0126',
#   ['KRAS',
#    'VEGFA',
#    'HBEGF',
#    'EREG',
#    'AREG',
#    'TGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PI3K-Akt signaling pathway']],
#  ['ki-8751',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'HBEGF',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['tyrphostin-51', ['PI3K-Akt signaling pathway', 'TGFA', 'EGF', 'AREG']],
#  ['cgs-15943', ['PI3K-Akt signaling pathway', 'AREG', 'TGFA']],
#  ['tyrphostin-ag-18', ['EGFR', 'EGFR', 'AREG', 'HBEGF']],
#  ['brd-k50634134', ['KRAS', 'EREG', 'AREG', 'TGFA']],
#  ['brd-k51608872',
#   ['PI3K-Akt signaling pathway',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['brd-k53932786',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'CERK',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['spiperone',
#   ['EGFL6',
#    'CERK',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['brd-k55487965',
#   ['EREG', 'AREG', 'PI3K-Akt signaling pathway', 'VEGF signaling pathway']],
#  ['brd-k55844427',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'HBEGF',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['azauridine', ['AREG']],
#  ['yc-1', ['EREG', 'EGFR', 'EGFR', 'MEGF9']],
#  ['brd-k61717269',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'TGFA',
#    'VEGFA',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['scoulerine', ['AREG', 'EGF']],
#  ['brd-k63245238', ['EGFR', 'EGFR']],
#  ['brd-k63770300', ['PI3K-Akt signaling pathway', 'AREG', 'EGF']],
#  ['quinoclamine',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'VEGFC',
#    'EGFL6']],
#  ['sib-1893', ['AREG']],
#  ['brd-k68313733', ['VEGFA', 'EGFL6', 'EREG', 'EGF']],
#  ['brd-k68548958', ['EGFR', 'EGFR']],
#  ['brd-k68588778',
#   ['VEGFA',
#    'EGFR',
#    'EGFR',
#    'EGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'ERK1 and ERK2 cascade (GO:0070371)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k69304050', ['EREG', 'EGF', 'PI3K-Akt signaling pathway']],
#  ['f-1566-0341',
#   ['PI3K-Akt signaling pathway', 'TGFA', 'HBEGF', 'EGFR', 'EGFR']],
#  ['u-99194', ['TGFA', 'HBEGF', 'EGFL6']],
#  ['brd-k72462751', ['EGF']],
#  ['brd-k73610817', ['EGFR', 'EGFR', 'TGFA', 'HBEGF', 'VEGFA', 'EREG']],
#  ['brd-k74690444',
#   ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'HBEGF', 'VEGFA', 'EGFL6']],
#  ['hnha',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'EREG',
#    'VEGFC',
#    'VEGFA',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['brd-k78388870', ['PI3K-Akt signaling pathway', 'AREG', 'EREG']],
#  ['cgp-60474', ['EGFL6']],
#  ['indolophenanthridine', ['VEGFC']],
#  ['brd-k79390395',
#   ['PI3K-Akt signaling pathway',
#    'TGFA',
#    'VEGFA',
#    'AREG',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['brd-k80346834', ['HBEGF', 'EREG']],
#  ['stk-397047',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)']],
#  ['brd-k81609421', ['PI3K-Akt signaling pathway', 'AREG', 'EREG', 'EGFL6']],
#  ['jl-7-128', ['TGFA', 'KRAS', 'HBEGF', 'EGFR', 'EGFR']],
#  ['nnc-05-2090', ['HBEGF', 'TGFA', 'EGF']],
#  ['dovitinib',
#   ['AREG',
#    'EREG',
#    'EGF',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'KRAS',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k88329126',
#   ['EGFR',
#    'EGFR',
#    'VEGFA',
#    'MEGF9',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['vu-0418934-2',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'TGFA', 'VEGFA']],
#  ['brd-k89224880',
#   ['PI3K-Akt signaling pathway', 'EGFR', 'EGFR', 'TGFA', 'HBEGF', 'VEGFA']],
#  ['prostratin',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'VEGFA',
#    'VEGFC',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)']],
#  ['brd-k92158425', ['AREG', 'EREG']],
#  ['', []],
#  ['ala-ala-phe-cmk', ['VEGFA', 'EREG', 'AREG', 'PI3K-Akt signaling pathway']],
#  ['erk-inhibitor-11e',
#   ['VEGFA', 'HBEGF', 'EREG', 'AREG', 'TGFA', 'PI3K-Akt signaling pathway']],
#  ['i-505056',
#   ['PI3K-Akt signaling pathway',
#    'AREG',
#    'EREG',
#    'TGFA',
#    'HBEGF',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['tws-119',
#   ['VEGFA',
#    'HBEGF',
#    'AREG',
#    'EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'positive regulation of ERK1 and ERK2 cascade (GO:0070374)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)',
#    'PI3K-Akt signaling pathway']],
#  ['spiramide',
#   ['EGFR',
#    'EGFR',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PI3K-Akt signaling pathway']],
#  ['brd-k95196255', ['EGFR', 'EGFR', 'AREG', 'TGFA', 'HBEGF', 'VEGFA']],
#  ['maz-51', ['AREG', 'EREG', 'EGFL6']],
#  ['sa-25547',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'VEGFA',
#    'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['tubaic-acid', ['AREG', 'EREG']],
#  ['pifithrin-mu',
#   ['PERK-mediated unfolded protein response (GO:0036499)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['skf-86002',
#   ['AREG', 'HBEGF', 'PERK-mediated unfolded protein response (GO:0036499)']],
#  ['src-kinase-inhibitor-ii',
#   ['PI3K-Akt signaling pathway',
#    'EGFR',
#    'EGFR',
#    'AREG',
#    'EREG',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'PERK-mediated unfolded protein response (GO:0036499)',
#    'negative regulation of ERK1 and ERK2 cascade (GO:0070373)']],
#  ['brd-k97936712',
#   ['PI3K-Akt signaling pathway',
#    'EGF',
#    'MEGF9',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['brd-k98173387',
#   ['PI3K-Akt signaling pathway', 'TGFA', 'VEGFA', 'EGFL6', 'EGFR', 'EGFR']],
#  ['brd-k98824517',
#   ['PI3K-Akt signaling pathway',
#    'HBEGF',
#    'VEGFA',
#    'CERK',
#    'regulation of ERK1 and ERK2 cascade (GO:0070372)',
#    'ERK1 and ERK2 cascade (GO:0070371)']],
#  ['brd-k99633092',
#   ['PERK-mediated unfolded protein response (GO:0036499)',
#    'ERK1 and ERK2 cascade (GO:0070371)']]]

# %%
lst2 = [item[0] for item in output_drugs]  # get names of all drugs. 
lst3 = [len(list(set((item[1])))) for item in output_drugs]  # count unique associations for each drug. 

ranked_names = [y for _, y in sorted(zip(lst3, lst2), reverse=True)]
ranked_association_counts = [x for x, _ in sorted(zip(lst3, lst2), reverse=True)]

while("" in ranked_names):
    ranked_names.remove("")
    
while(0 in ranked_association_counts):
    ranked_association_counts.remove(0)

ranked_df = pd.DataFrame(
    {'Drug': ranked_names,
     'Associative count': ranked_association_counts,
    })
display(ranked_df)

n = 5
top_drugs = ranked_df.head(n)["Drug"].tolist()

print("Your top " + str(n) + " suggested drugs: ")
for i in range(0, n):
    name = top_drugs[i]
    associations = list(filter(lambda record: record[0] == name, output_drugs))[0][1]
    print(name)
    print("which targets: ")
    print(str(list(set(associations))))
# Out:
#               Drug  Associative count
# 0        pazopanib                 12
# 1           ym-155                 11
# 2      saracatinib                 11
# 3       prostratin                 11
# 4       irinotecan                 10
# ..             ...                ...
# 304  brd-k62300190                  1
# 305  brd-a04172077                  1
# 306     azauridine                  1
# 307      ambelline                  1
# 308         7b-cis                  1
#
# [309 rows x 2 columns]
# Your top 5 suggested drugs:
# pazopanib
# which targets:
# ['KRAS', 'NRAS', 'PERK-mediated unfolded protein response (GO:0036499)', 'regulation of ERK1 and ERK2 cascade (GO:0070372)', 'VEGFA', 'AREG', 'positive regulation of ERK1 and ERK2 cascade (GO:0070374)', 'EGF', 'VEGFB', 'VEGFR inhibitor', 'EGFR', 'TGFA']
# ym-155
# which targets:
# ['ERK1 and ERK2 cascade (GO:0070371)', 'HBEGF', 'negative regulation of ERK1 and ERK2 cascade (GO:0070373)', 'regulation of ERK1 and ERK2 cascade (GO:0070372)', 'AREG', 'VEGFA', 'PI3K-Akt signaling pathway', 'EREG', 'CERK', 'EGFR', 'TGFA']
# saracatinib
# which targets:
# ['HBEGF', 'VEGFC', 'KRAS', 'NRAS', 'AREG', 'VEGFA', 'PI3K-Akt signaling pathway', 'EGF', 'EREG', 'EGFR', 'TGFA']
# prostratin
# which targets:
# ['HBEGF', 'VEGFC', 'regulation of ERK1 and ERK2 cascade (GO:0070372)', 'AREG', 'VEGFA', 'PI3K-Akt signaling pathway', 'positive regulation of ERK1 and ERK2 cascade (GO:0070374)', 'EREG', 'MEGF9', 'EGFR', 'TGFA']
# irinotecan
# which targets:
# ['HBEGF', 'KRAS', 'NRAS', 'regulation of ERK1 and ERK2 cascade (GO:0070372)', 'AREG', 'VEGFA', 'PI3K-Akt signaling pathway', 'EREG', 'EGFR', 'TGFA']

# %%
# from IPython.display import display_html
# from itertools import chain,cycle
# def display_side_by_side(*args,titles=cycle([''])):
#     html_str=''
#     for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
#         html_str+='<th style="text-align:center"><td style="vertical-align:top">'
#         html_str+=f'<h2>{title}</h2>'
#         html_str+=df.to_html().replace('table','table style="display:inline"')
#         html_str+='</td></th>'
#     display_html(html_str,raw=True)
    
# display_side_by_side(ranked_df),df2,df1, titles=['Foo','Foo Bar'])

# %%
# with open('empty_csc.xml') as f:
#     lines = f.readlines()
# # print(lines)
