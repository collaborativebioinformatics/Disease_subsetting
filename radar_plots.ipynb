# %%
import xml.etree.ElementTree as et
import numpy as np
import matplotlib.pyplot as plt

# %%
hsa = et.parse("hsa00140.xml")

# %%
root = hsa.getroot()

# %%
for child in root[1]:
    pathway = child.attrib['name'].replace('TITLE:', '')

# %%
for i in range(len(root)):
    for child in root[i]:
        try:
            print(child.attrib)
        except:
            pass
    break
# Out:
# {'name': 'HSD17B1, 17-beta-HSD, 20-alpha-HSD, E2DH, EDH17B2, EDHB17, HSD17, SDR28C1...', 'fgcolor': '#000000', 'bgcolor': '#BFFFBF', 'type': 'rectangle', 'x': '899', 'y': '1122', 'width': '46', 'height': '17'}

# %%
for child in root[0]:
    print(child.attrib)
# Out:
# {'name': 'HSD17B1, 17-beta-HSD, 20-alpha-HSD, E2DH, EDH17B2, EDHB17, HSD17, SDR28C1...', 'fgcolor': '#000000', 'bgcolor': '#BFFFBF', 'type': 'rectangle', 'x': '899', 'y': '1122', 'width': '46', 'height': '17'}

# %%
genes = [gene for gene in root[0].attrib['name'].split(' ')]

# %%
print(genes)
# Out:
# ['hsa:3292', 'hsa:3294', 'hsa:51144', 'hsa:51478', 'hsa:7923', 'hsa:8630']

# %%
expr = [0, 1, 0, 1, 1, 1]

# %%
label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(x))

plt.figure(figsize=(8, 8))
plt.subplot(polar=True)
plt.plot(label_loc, x, label=pathway)
plt.title('Pathway Analysis', size=20)
lines, labels = plt.thetagrids(np.degrees(label_loc), labels=genes)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jz/6x71ckj13c31lbpnxzk_tm640000gn/T/ipykernel_3210/2548373637.py in <module>
#       5 plt.plot(label_loc, x, label=pathway)
#       6 plt.title('Pathway Analysis', size=20)
# ----> 7 lines, labels = plt.thetagrids(np.degrees(label_loc), labels=genes)
#       8 plt.legend()
#       9 plt.show()
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/pyplot.py in thetagrids(angles, labels, fmt, **kwargs)
#    2014     else:
#    2015         lines, labels = ax.set_thetagrids(angles,
# -> 2016                                           labels=labels, fmt=fmt, **kwargs)
#    2017     return lines, labels
#    2018
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/projections/polar.py in set_thetagrids(self, angles, labels, fmt, **kwargs)
#    1334         self.set_xticks(angles)
#    1335         if labels is not None:
# -> 1336             self.set_xticklabels(labels)
#    1337         elif fmt is not None:
#    1338             self.xaxis.set_major_formatter(mticker.FormatStrFormatter(fmt))
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1793         if fontdict is not None:
#    1794             kwargs.update(fontdict)
# -> 1795         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1796
#    1797     def set_ticks(self, ticks, *, minor=False):
#
# ~/opt/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1715             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1716                 raise ValueError(
# -> 1717                     "The number of FixedLocator locations"
#    1718                     f" ({len(locator.locs)}), usually from a call to"
#    1719                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (7), usually from a call to set_ticks, does not match the number of ticklabels (6).
